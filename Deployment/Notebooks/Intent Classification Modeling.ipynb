# %% [markdown]
# ### Importing The Libraries

# %%
import numpy as np
import pickle
import random
import yaml

import nltk 
import spacy
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD

lemmatizer = WordNetLemmatizer()
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ### Preprocessing Dataset

# %%
words=[]
classes = []
documents = []

ignore_words = ['?','!']

data_file = open('./data/intents.yaml').read()
intents = yaml.safe_load(data_file)

for intent in intents['intent']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = word_tokenize(pattern)
        words.extend(w)
        
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

# sort classes
classes = sorted(list(set(classes)))

# documents = combination between patterns and intentsr
print (len(documents), "documents")
print("_" * 80)

# classes = intents
print ("Num of Intents",len(classes),'\n',classes)
print("_" * 80)

# words =  vocabulary
print (len(words), "unique words")
# Out:
# 548 documents
# ________________________________________________________________________________
# Num of Intents 13
#  ['Cooking', 'Datetime', 'Goodbye', 'Greeting', 'Info_Request', 'Iot', 'Joke', 'News', 'PlayMusic', 'Reminder', 'Thanks', 'Transport', 'Weather']
# ________________________________________________________________________________
# 517 unique words

# %% [markdown]
# ### Create Training Data

# %%
# create our training data
train = []

# create an empty array for our output
output_empty = [0] * len(classes)

# training set, bag of words for each sentence
for doc in documents:
    
    # initialize our bag of words
    bag = []
    
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    train.append([bag, output_row])
    
# shuffle our features and turn into np.array
random.shuffle(train)
train = np.array(train,dtype=object)

# create train and test lists. X - patterns, Y - intents
train_x = list(train[:,0])
train_y = list(train[:,1])
print("Training data created")
# Out:
# Training data created

# %% [markdown]
# ### Model Preparation & Training

# %%
# Create model - 3 layers. 
# 3rd output layer contains number of neurons equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent 
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
history = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
# Out:
# Epoch 1/200
# 110/110 [==============================] - 2s 1ms/step - loss: 2.0780 - accuracy: 0.3193
# Epoch 2/200
# 110/110 [==============================] - 0s 2ms/step - loss: 1.3821 - accuracy: 0.5730
# Epoch 3/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.9806 - accuracy: 0.7208
# Epoch 4/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.7915 - accuracy: 0.7518
# Epoch 5/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.6211 - accuracy: 0.8212
# Epoch 6/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.4800 - accuracy: 0.8613
# Epoch 7/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.3627 - accuracy: 0.8942
# Epoch 8/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.3360 - accuracy: 0.8978
# Epoch 9/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.2860 - accuracy: 0.9106
# Epoch 10/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.2692 - accuracy: 0.9179
# Epoch 11/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.2313 - accuracy: 0.9361
# Epoch 12/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.1917 - accuracy: 0.9380
# Epoch 13/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.1909 - accuracy: 0.9453
# Epoch 14/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.1604 - accuracy: 0.9526
# Epoch 15/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.1578 - accuracy: 0.9434
# Epoch 16/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.1186 - accuracy: 0.9690
# Epoch 17/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.1210 - accuracy: 0.9617
# Epoch 18/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.1189 - accuracy: 0.9580
# Epoch 19/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.1146 - accuracy: 0.9617
# Epoch 20/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.1091 - accuracy: 0.9763
# Epoch 21/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.1235 - accuracy: 0.9672
# Epoch 22/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0840 - accuracy: 0.9799
# Epoch 23/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0879 - accuracy: 0.9745
# Epoch 24/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.1162 - accuracy: 0.9653
# Epoch 25/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.1005 - accuracy: 0.9672
# Epoch 26/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0926 - accuracy: 0.9726
# Epoch 27/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0777 - accuracy: 0.9836
# Epoch 28/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0596 - accuracy: 0.9818
# Epoch 29/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0801 - accuracy: 0.9781
# Epoch 30/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0553 - accuracy: 0.9891
# Epoch 31/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0463 - accuracy: 0.9891
# Epoch 32/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0387 - accuracy: 0.9964
# Epoch 33/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0442 - accuracy: 0.9927
# Epoch 34/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0304 - accuracy: 0.9945
# Epoch 35/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0512 - accuracy: 0.9872
# Epoch 36/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0436 - accuracy: 0.9891
# Epoch 37/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0570 - accuracy: 0.9818
# Epoch 38/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 0.9891
# Epoch 39/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0584 - accuracy: 0.9818
# Epoch 40/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0534 - accuracy: 0.9818
# Epoch 41/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0419 - accuracy: 0.9891
# Epoch 42/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0563 - accuracy: 0.9909
# Epoch 43/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0348 - accuracy: 0.9927
# Epoch 44/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0285 - accuracy: 0.9927
# Epoch 45/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0392 - accuracy: 0.9909
# Epoch 46/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0298 - accuracy: 0.9909
# Epoch 47/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0245 - accuracy: 0.9927
# Epoch 48/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0360 - accuracy: 0.9872
# Epoch 49/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0456 - accuracy: 0.9891
# Epoch 50/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0267 - accuracy: 0.9891
# Epoch 51/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0261 - accuracy: 0.9909
# Epoch 52/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0319 - accuracy: 0.9927
# Epoch 53/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0358 - accuracy: 0.9909
# Epoch 54/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0216 - accuracy: 0.9964
# Epoch 55/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0289 - accuracy: 0.9909
# Epoch 56/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0227 - accuracy: 0.9945
# Epoch 57/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0176 - accuracy: 0.9982
# Epoch 58/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0200 - accuracy: 0.9964
# Epoch 59/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0234 - accuracy: 0.9982
# Epoch 60/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.9964
# Epoch 61/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0463 - accuracy: 0.9909
# Epoch 62/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0222 - accuracy: 0.9927
# Epoch 63/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.9964
# Epoch 64/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0263 - accuracy: 0.9872
# Epoch 65/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0130 - accuracy: 0.9964
# Epoch 66/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0168 - accuracy: 0.9964
# Epoch 67/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0309 - accuracy: 0.9927
# Epoch 68/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0233 - accuracy: 0.9964
# Epoch 69/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 0.9945
# Epoch 70/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 71/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 72/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0251 - accuracy: 0.9909
# Epoch 73/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 0.9927
# Epoch 74/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0115 - accuracy: 0.9945
# Epoch 75/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 0.9945
# Epoch 76/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.9945
# Epoch 77/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0233 - accuracy: 0.9909
# Epoch 78/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0231 - accuracy: 0.9909
# Epoch 79/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 0.9964
# Epoch 80/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0275 - accuracy: 0.9891
# Epoch 81/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0382 - accuracy: 0.9891
# Epoch 82/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0205 - accuracy: 0.9945
# Epoch 83/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0154 - accuracy: 0.9964
# Epoch 84/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0289 - accuracy: 0.9945
# Epoch 85/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0143 - accuracy: 0.9964
# Epoch 86/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0286 - accuracy: 0.9909
# Epoch 87/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 0.9909
# Epoch 88/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0226 - accuracy: 0.9945
# Epoch 89/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 0.9982
# Epoch 90/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 0.9982
# Epoch 91/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.9945
# Epoch 92/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0311 - accuracy: 0.9872
# Epoch 93/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0087 - accuracy: 0.9982
# Epoch 94/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 0.9964
# Epoch 95/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0183 - accuracy: 0.9945
# Epoch 96/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0138 - accuracy: 0.9964
# Epoch 97/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 0.9945
# Epoch 98/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 0.9982
# Epoch 99/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0119 - accuracy: 0.9982
# Epoch 100/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 0.9982
# Epoch 101/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 0.9982
# Epoch 102/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 103/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 0.9982
# Epoch 104/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0254 - accuracy: 0.9927
# Epoch 105/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 106/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0147 - accuracy: 0.9945
# Epoch 107/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 0.9964
# Epoch 108/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 0.9964
# Epoch 109/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 0.9964
# Epoch 110/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0166 - accuracy: 0.9964
# Epoch 111/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0121 - accuracy: 0.9964
# Epoch 112/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0126 - accuracy: 0.9964
# Epoch 113/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0146 - accuracy: 0.9964
# Epoch 114/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 0.9982
# Epoch 115/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0145 - accuracy: 0.9927
# Epoch 116/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0284 - accuracy: 0.9945
# Epoch 117/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0171 - accuracy: 0.9927
# Epoch 118/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 0.9927
# Epoch 119/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 120/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0169 - accuracy: 0.9945
# Epoch 121/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0132 - accuracy: 0.9945
# Epoch 122/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0122 - accuracy: 0.9964
# Epoch 123/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0188 - accuracy: 0.9927
# Epoch 124/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 0.9964
# Epoch 125/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0206 - accuracy: 0.9945
# Epoch 126/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 0.9982
# Epoch 127/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0126 - accuracy: 0.9927
# Epoch 128/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 129/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 0.9964
# Epoch 130/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 131/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0087 - accuracy: 0.9982
# Epoch 132/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0145 - accuracy: 0.9982
# Epoch 133/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 134/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0112 - accuracy: 0.9964
# Epoch 135/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 0.9964
# Epoch 136/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 0.9927
# Epoch 137/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 138/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 0.9964
# Epoch 139/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 0.9964
# Epoch 140/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 141/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0224 - accuracy: 0.9964
# Epoch 142/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0129 - accuracy: 0.9964
# Epoch 143/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0089 - accuracy: 0.9964
# Epoch 144/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0173 - accuracy: 0.9945
# Epoch 145/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0125 - accuracy: 0.9945
# Epoch 146/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 0.9982
# Epoch 147/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0133 - accuracy: 0.9945
# Epoch 148/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0159 - accuracy: 0.9927
# Epoch 149/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 150/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 0.9964
# Epoch 151/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 152/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0212 - accuracy: 0.9964
# Epoch 153/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0101 - accuracy: 0.9945
# Epoch 154/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0166 - accuracy: 0.9945
# Epoch 155/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0211 - accuracy: 0.9945
# Epoch 156/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 0.9927
# Epoch 157/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 0.9982
# Epoch 158/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 159/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0106 - accuracy: 0.9964
# Epoch 160/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0122 - accuracy: 0.9964
# Epoch 161/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0109 - accuracy: 0.9945
# Epoch 162/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 0.9982
# Epoch 163/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 0.9945
# Epoch 164/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 165/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 166/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0121 - accuracy: 0.9964
# Epoch 167/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 168/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0085 - accuracy: 0.9982
# Epoch 169/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 170/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0149 - accuracy: 0.9945
# Epoch 171/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 172/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0144 - accuracy: 0.9964
# Epoch 173/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0072 - accuracy: 0.9982
# Epoch 174/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0054 - accuracy: 0.9982
# Epoch 175/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0065 - accuracy: 0.9982
# Epoch 176/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 0.9982
# Epoch 177/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 0.9945
# Epoch 178/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 179/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 180/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 181/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0134 - accuracy: 0.9964
# Epoch 182/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0090 - accuracy: 0.9964
# Epoch 183/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 184/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 0.9982
# Epoch 185/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 0.9964
# Epoch 186/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0054 - accuracy: 0.9982
# Epoch 187/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0113 - accuracy: 0.9964
# Epoch 188/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 0.9964
# Epoch 189/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 0.9945
# Epoch 190/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0035 - accuracy: 0.9982
# Epoch 191/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0051 - accuracy: 0.9982
# Epoch 192/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 193/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 0.9982
# Epoch 194/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0031 - accuracy: 0.9982
# Epoch 195/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0128 - accuracy: 0.9964
# Epoch 196/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0127 - accuracy: 0.9964
# Epoch 197/200
# 110/110 [==============================] - 0s 1ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 198/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 199/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 200/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 0.9945

# %% [markdown]
# ### Saving Model, Classes and Words

# %%
model.save('Model.h5',history)

with open('classes.pkl','wb') as file:  
    pickle.dump(classes,file)

with open('words.pkl','wb') as file:  
    pickle.dump(words,file)
